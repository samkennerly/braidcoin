# %% [markdown]
# # networkx
#
# try using networkx for graph drawing

# %%
# %load_ext autoreload
# %autoreload all

# %%
import networkx as nx
import matplotlib.pyplot as plt

from minernet import *

# %%
beads = [
    Bead(0),
    Bead(1, parents={0}),
    Bead(2, parents={0}),
    Bead(3, parents={1,2}),
    Bead(4, parents={3}),
    Bead(5, parents={4}),
    Bead(6, parents={4}),
    Bead(7, parents={4}),
    Bead(8, parents={5,6,7}),
    Bead(9, parents={8}),
    Bead(10, parents={8}),
    Bead(11, parents={10}),
    Bead(12, parents={10}),
    Bead(13, parents={9}),
    Bead(14, parents={11,12}),
    Bead(15, parents={13,14}),
    Bead(16, parents={15}),
]
braid = Braid(beads)
braid
# Out:
# <Braid with 17 beads>

# %%
_ = braid.plot()
